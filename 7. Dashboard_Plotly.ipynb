# %%
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# !pip install werkzeug==2.0.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dash in c:\users\edder\appdata\roaming\python\python312\site-packages (1.19.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\programdata\anacondamarch2025\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: flask-compress in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash) (1.17)
# Requirement already satisfied: plotly in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash) (6.0.1)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash) (4.11.2)
# Requirement already satisfied: future in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask>=1.0.4->dash) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask>=1.0.4->dash) (1.6.2)
# Requirement already satisfied: brotli in c:\programdata\anacondamarch2025\lib\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: zstandard in c:\programdata\anacondamarch2025\lib\site-packages (from flask-compress->dash) (0.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\edder\appdata\roaming\python\python312\site-packages (from plotly->dash) (1.35.0)
# Requirement already satisfied: packaging in c:\programdata\anacondamarch2025\lib\site-packages (from plotly->dash) (24.1)
# Requirement already satisfied: colorama in c:\programdata\anacondamarch2025\lib\site-packages (from click>=8.1.3->Flask>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anacondamarch2025\lib\site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash) (2.1.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dash==1.19.0 in c:\users\edder\appdata\roaming\python\python312\site-packages (1.19.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\programdata\anacondamarch2025\lib\site-packages (from dash==1.19.0) (3.0.3)
# Requirement already satisfied: flask-compress in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash==1.19.0) (1.17)
# Requirement already satisfied: plotly in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash==1.19.0) (6.0.1)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: future in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash==1.19.0) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (1.6.2)
# Requirement already satisfied: brotli in c:\programdata\anacondamarch2025\lib\site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: zstandard in c:\programdata\anacondamarch2025\lib\site-packages (from flask-compress->dash==1.19.0) (0.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\edder\appdata\roaming\python\python312\site-packages (from plotly->dash==1.19.0) (1.35.0)
# Requirement already satisfied: packaging in c:\programdata\anacondamarch2025\lib\site-packages (from plotly->dash==1.19.0) (24.1)
# Requirement already satisfied: colorama in c:\programdata\anacondamarch2025\lib\site-packages (from click>=8.1.3->Flask>=1.0.4->dash==1.19.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anacondamarch2025\lib\site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash==1.19.0) (2.1.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter_dash in c:\users\edder\appdata\roaming\python\python312\site-packages (0.4.2)
# Requirement already satisfied: dash in c:\users\edder\appdata\roaming\python\python312\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: requests in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter_dash) (2.32.3)
# Requirement already satisfied: flask in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter_dash) (3.0.3)
# Requirement already satisfied: retrying in c:\users\edder\appdata\roaming\python\python312\site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: ipython in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter_dash) (8.27.0)
# Requirement already satisfied: ipykernel in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter_dash) (6.28.0)
# Requirement already satisfied: ansi2html in c:\users\edder\appdata\roaming\python\python312\site-packages (from jupyter_dash) (1.9.2)
# Requirement already satisfied: nest-asyncio in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: flask-compress in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash->jupyter_dash) (1.17)
# Requirement already satisfied: plotly in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash->jupyter_dash) (6.0.1)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: future in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash->jupyter_dash) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\programdata\anacondamarch2025\lib\site-packages (from flask->jupyter_dash) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\programdata\anacondamarch2025\lib\site-packages (from flask->jupyter_dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\programdata\anacondamarch2025\lib\site-packages (from flask->jupyter_dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\programdata\anacondamarch2025\lib\site-packages (from flask->jupyter_dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\programdata\anacondamarch2025\lib\site-packages (from flask->jupyter_dash) (1.6.2)
# Requirement already satisfied: comm>=0.1.1 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter_dash) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter_dash) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter_dash) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter_dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter_dash) (0.1.6)
# Requirement already satisfied: packaging in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter_dash) (24.1)
# Requirement already satisfied: psutil in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter_dash) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter_dash) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter_dash) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter_dash) (5.14.3)
# Requirement already satisfied: decorator in c:\programdata\anacondamarch2025\lib\site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anacondamarch2025\lib\site-packages (from ipython->jupyter_dash) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\programdata\anacondamarch2025\lib\site-packages (from ipython->jupyter_dash) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anacondamarch2025\lib\site-packages (from ipython->jupyter_dash) (2.15.1)
# Requirement already satisfied: stack-data in c:\programdata\anacondamarch2025\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: colorama in c:\programdata\anacondamarch2025\lib\site-packages (from ipython->jupyter_dash) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anacondamarch2025\lib\site-packages (from requests->jupyter_dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anacondamarch2025\lib\site-packages (from requests->jupyter_dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anacondamarch2025\lib\site-packages (from requests->jupyter_dash) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anacondamarch2025\lib\site-packages (from requests->jupyter_dash) (2024.8.30)
# Requirement already satisfied: six>=1.7.0 in c:\programdata\anacondamarch2025\lib\site-packages (from retrying->jupyter_dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\programdata\anacondamarch2025\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anacondamarch2025\lib\site-packages (from Jinja2>=3.1.2->flask->jupyter_dash) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter_dash) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter_dash) (305.1)
# Requirement already satisfied: wcwidth in c:\programdata\anacondamarch2025\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: brotli in c:\programdata\anacondamarch2025\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: zstandard in c:\programdata\anacondamarch2025\lib\site-packages (from flask-compress->dash->jupyter_dash) (0.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\edder\appdata\roaming\python\python312\site-packages (from plotly->dash->jupyter_dash) (1.35.0)
# Requirement already satisfied: executing in c:\programdata\anacondamarch2025\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: asttokens in c:\programdata\anacondamarch2025\lib\site-packages (from stack-data->ipython->jupyter_dash) (2.0.5)
# Requirement already satisfied: pure-eval in c:\programdata\anacondamarch2025\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly in c:\users\edder\appdata\roaming\python\python312\site-packages (6.0.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\edder\appdata\roaming\python\python312\site-packages (from plotly) (1.35.0)
# Requirement already satisfied: packaging in c:\programdata\anacondamarch2025\lib\site-packages (from plotly) (24.1)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting werkzeug==2.0.3
#   Downloading Werkzeug-2.0.3-py3-none-any.whl.metadata (4.5 kB)
# Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
# Installing collected packages: werkzeug
# Successfully installed werkzeug-2.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 3.0.3 requires Werkzeug>=3.0.0, but you have werkzeug 2.0.3 which is incompatible.

# %%
import pandas as pd
# !pip install -U dash
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dash in c:\users\edder\appdata\roaming\python\python312\site-packages (1.19.0)
# Collecting dash
#   Using cached dash-3.0.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\programdata\anacondamarch2025\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash) (2.0.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash) (6.0.1)
# Requirement already satisfied: importlib-metadata in c:\programdata\anacondamarch2025\lib\site-packages (from dash) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\programdata\anacondamarch2025\lib\site-packages (from dash) (4.11.0)
# Requirement already satisfied: requests in c:\programdata\anacondamarch2025\lib\site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\programdata\anacondamarch2025\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\programdata\anacondamarch2025\lib\site-packages (from dash) (75.1.0)
# Collecting Werkzeug<3.1 (from dash)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\programdata\anacondamarch2025\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (1.6.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\edder\appdata\roaming\python\python312\site-packages (from plotly>=5.0.0->dash) (1.35.0)
# Requirement already satisfied: packaging in c:\programdata\anacondamarch2025\lib\site-packages (from plotly>=5.0.0->dash) (24.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anacondamarch2025\lib\site-packages (from Werkzeug<3.1->dash) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anacondamarch2025\lib\site-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anacondamarch2025\lib\site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anacondamarch2025\lib\site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anacondamarch2025\lib\site-packages (from requests->dash) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anacondamarch2025\lib\site-packages (from requests->dash) (2024.8.30)
# Requirement already satisfied: six>=1.7.0 in c:\programdata\anacondamarch2025\lib\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: colorama in c:\programdata\anacondamarch2025\lib\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Using cached dash-3.0.3-py3-none-any.whl (8.0 MB)
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Installing collected packages: Werkzeug, dash
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.0.3
#     Uninstalling Werkzeug-2.0.3:
#       Successfully uninstalled Werkzeug-2.0.3
#   Attempting uninstall: dash
#     Found existing installation: dash 1.19.0
#     Uninstalling dash-1.19.0:
#       Successfully uninstalled dash-1.19.0
# Successfully installed Werkzeug-3.0.6 dash-3.0.3
#   WARNING: The scripts dash-generate-components.exe, dash-update-components.exe and renderer.exe are installed in 'C:\Users\edder\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !pip install jupyter-dash
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter-dash in c:\users\edder\appdata\roaming\python\python312\site-packages (0.4.2)
# Requirement already satisfied: dash in c:\users\edder\appdata\roaming\python\python312\site-packages (from jupyter-dash) (3.0.3)
# Requirement already satisfied: requests in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter-dash) (2.32.3)
# Requirement already satisfied: flask in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter-dash) (3.0.3)
# Requirement already satisfied: retrying in c:\users\edder\appdata\roaming\python\python312\site-packages (from jupyter-dash) (1.3.4)
# Requirement already satisfied: ipython in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter-dash) (8.27.0)
# Requirement already satisfied: ipykernel in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter-dash) (6.28.0)
# Requirement already satisfied: ansi2html in c:\users\edder\appdata\roaming\python\python312\site-packages (from jupyter-dash) (1.9.2)
# Requirement already satisfied: nest-asyncio in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter-dash) (1.6.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash->jupyter-dash) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\edder\appdata\roaming\python\python312\site-packages (from dash->jupyter-dash) (6.0.1)
# Requirement already satisfied: importlib-metadata in c:\programdata\anacondamarch2025\lib\site-packages (from dash->jupyter-dash) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\programdata\anacondamarch2025\lib\site-packages (from dash->jupyter-dash) (4.11.0)
# Requirement already satisfied: setuptools in c:\programdata\anacondamarch2025\lib\site-packages (from dash->jupyter-dash) (75.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\programdata\anacondamarch2025\lib\site-packages (from flask->jupyter-dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\programdata\anacondamarch2025\lib\site-packages (from flask->jupyter-dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\programdata\anacondamarch2025\lib\site-packages (from flask->jupyter-dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\programdata\anacondamarch2025\lib\site-packages (from flask->jupyter-dash) (1.6.2)
# Requirement already satisfied: comm>=0.1.1 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter-dash) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter-dash) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter-dash) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter-dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter-dash) (0.1.6)
# Requirement already satisfied: packaging in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter-dash) (24.1)
# Requirement already satisfied: psutil in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter-dash) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter-dash) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter-dash) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\programdata\anacondamarch2025\lib\site-packages (from ipykernel->jupyter-dash) (5.14.3)
# Requirement already satisfied: decorator in c:\programdata\anacondamarch2025\lib\site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anacondamarch2025\lib\site-packages (from ipython->jupyter-dash) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\programdata\anacondamarch2025\lib\site-packages (from ipython->jupyter-dash) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anacondamarch2025\lib\site-packages (from ipython->jupyter-dash) (2.15.1)
# Requirement already satisfied: stack-data in c:\programdata\anacondamarch2025\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: colorama in c:\programdata\anacondamarch2025\lib\site-packages (from ipython->jupyter-dash) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anacondamarch2025\lib\site-packages (from requests->jupyter-dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anacondamarch2025\lib\site-packages (from requests->jupyter-dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anacondamarch2025\lib\site-packages (from requests->jupyter-dash) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anacondamarch2025\lib\site-packages (from requests->jupyter-dash) (2024.8.30)
# Requirement already satisfied: six>=1.7.0 in c:\programdata\anacondamarch2025\lib\site-packages (from retrying->jupyter-dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\programdata\anacondamarch2025\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anacondamarch2025\lib\site-packages (from Jinja2>=3.1.2->flask->jupyter-dash) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\programdata\anacondamarch2025\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (305.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\edder\appdata\roaming\python\python312\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (1.35.0)
# Requirement already satisfied: wcwidth in c:\programdata\anacondamarch2025\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anacondamarch2025\lib\site-packages (from importlib-metadata->dash->jupyter-dash) (3.17.0)
# Requirement already satisfied: executing in c:\programdata\anacondamarch2025\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: asttokens in c:\programdata\anacondamarch2025\lib\site-packages (from stack-data->ipython->jupyter-dash) (2.0.5)
# Requirement already satisfied: pure-eval in c:\programdata\anacondamarch2025\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.2.2)

# %%
# Import required libraries
from jupyter_dash import JupyterDash
app = JupyterDash(__name__)
import pandas as pd
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px

from jupyter_dash import JupyterDash

# Replace dash.Dash with JupyterDash
# app.run_server(mode='inline')
# from jupyter_dash import JupyterDash
# app = JupyterDash(__name__)

# Run the app in inline mode
# app.run_server(mode='inline')

# Read the SpaceX launch data into a pandas dataframe
spacex_df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv')
spacex_df
# Out:
# C:\Users\edder\AppData\Roaming\Python\Python312\site-packages\dash\dash.py:586: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
#     Unnamed: 0  Flight Number   Launch Site  class  Payload Mass (kg)  \
# 0            0              1   CCAFS LC-40      0               0.00
# 1            1              2   CCAFS LC-40      0               0.00
# 2            2              3   CCAFS LC-40      0             525.00
# 3            3              4   CCAFS LC-40      0             500.00
# 4            4              5   CCAFS LC-40      0             677.00
# 5            5              7   CCAFS LC-40      0            3170.00
# 6            6              8   CCAFS LC-40      0            3325.00
# 7            7              9   CCAFS LC-40      0            2296.00
# 8            8             10   CCAFS LC-40      0            1316.00
# 9            9             11   CCAFS LC-40      0            4535.00
# 10          10             12   CCAFS LC-40      0            4428.00
# 11          11             13   CCAFS LC-40      0            2216.00
# 12          12             14   CCAFS LC-40      0            2395.00
# 13          13             15   CCAFS LC-40      0             570.00
# 14          14             16   CCAFS LC-40      0            4159.00
# 15          15             17   CCAFS LC-40      0            1898.00
# 16          16             18   CCAFS LC-40      0            4707.00
# 17          17             19   CCAFS LC-40      1            1952.00
# 18          18             20   CCAFS LC-40      1            2034.00
# 19          19             22   CCAFS LC-40      0            5271.00
# 20          20             23   CCAFS LC-40      1            3136.00
# 21          21             24   CCAFS LC-40      1            4696.00
# 22          22             25   CCAFS LC-40      1            3100.00
# 23          23             26   CCAFS LC-40      0            3600.00
# 24          24             27   CCAFS LC-40      1            2257.00
# 25          25             28   CCAFS LC-40      1            4600.00
# 26          26              6   VAFB SLC-4E      0             500.00
# 27          27             21   VAFB SLC-4E      0             553.00
# 28          28             29   VAFB SLC-4E      1            9600.00
# 29          29             37   VAFB SLC-4E      1            9600.00
# 30          30             40   VAFB SLC-4E      1             475.00
# 31          31             42   VAFB SLC-4E      1            9600.00
# 32          32             46   VAFB SLC-4E      0            9600.00
# 33          33             49   VAFB SLC-4E      0            2150.00
# 34          34             51   VAFB SLC-4E      0            9600.00
# 35          35             55   VAFB SLC-4E      0            6460.00
# 36          36             30    KSC LC-39A      1            2490.00
# 37          37             31    KSC LC-39A      0            5600.00
# 38          38             32    KSC LC-39A      1            5300.00
# 39          39             33    KSC LC-39A      1            3696.65
# 40          40             34    KSC LC-39A      0            6070.00
# 41          41             35    KSC LC-39A      1            2708.00
# 42          42             36    KSC LC-39A      1            3669.00
# 43          43             38    KSC LC-39A      0            6761.00
# 44          44             39    KSC LC-39A      1            3310.00
# 45          45             41    KSC LC-39A      1            4990.00
# 46          46             43    KSC LC-39A      1            5200.00
# 47          47             44    KSC LC-39A      1            3500.00
# 48          48             54    KSC LC-39A      1            3600.00
# 49          49             45  CCAFS SLC-40      1            2205.00
# 50          50             47  CCAFS SLC-40      1            3696.65
# 51          51             48  CCAFS SLC-40      0            4230.00
# 52          52             50  CCAFS SLC-40      0            6092.00
# 53          53             52  CCAFS SLC-40      0            2647.00
# 54          54             53  CCAFS SLC-40      1             362.00
# 55          55             56  CCAFS SLC-40      0            5384.00
#
#    Booster Version Booster Version Category
# 0   F9 v1.0  B0003                     v1.0
# 1   F9 v1.0  B0004                     v1.0
# 2   F9 v1.0  B0005                     v1.0
# 3   F9 v1.0  B0006                     v1.0
# 4   F9 v1.0  B0007                     v1.0
# 5          F9 v1.1                     v1.1
# 6          F9 v1.1                     v1.1
# 7          F9 v1.1                     v1.1
# 8          F9 v1.1                     v1.1
# 9          F9 v1.1                     v1.1
# 10   F9 v1.1 B1011                     v1.1
# 11   F9 v1.1 B1010                     v1.1
# 12   F9 v1.1 B1012                     v1.1
# 13   F9 v1.1 B1013                     v1.1
# 14   F9 v1.1 B1014                     v1.1
# 15   F9 v1.1 B1015                     v1.1
# 16   F9 v1.1 B1016                     v1.1
# 17   F9 v1.1 B1018                     v1.1
# 18     F9 FT B1019                       FT
# 19     F9 FT B1020                       FT
# 20   F9 FT B1021.1                       FT
# 21     F9 FT B1022                       FT
# 22   F9 FT B1023.1                       FT
# 23     F9 FT B1024                       FT
# 24   F9 FT B1025.1                       FT
# 25     F9 FT B1026                       FT
# 26  F9 v1.1  B1003                     v1.1
# 27   F9 v1.1 B1017                     v1.1
# 28   F9 FT B1029.1                       FT
# 29   F9 FT B1036.1                       FT
# 30   F9 FT B1038.1                       FT
# 31   F9 B4 B1041.1                       B4
# 32  F9 FT  B1036.2                       FT
# 33  F9 FT  B1038.2                       FT
# 34  F9 B4  B1041.2                       B4
# 35  F9 B4  B1043.2                       B4
# 36   F9 FT B1031.1                       FT
# 37     F9 FT B1030                       FT
# 38  F9 FT  B1021.2                       FT
# 39   F9 FT B1032.1                       FT
# 40     F9 FT B1034                       FT
# 41   F9 FT B1035.1                       FT
# 42  F9 FT  B1029.2                       FT
# 43     F9 FT B1037                       FT
# 44   F9 B4 B1039.1                       B4
# 45   F9 B4 B1040.1                       B4
# 46  F9 FT  B1031.2                       FT
# 47   F9 B4 B1042.1                       B4
# 48  F9 B5  B1046.1                       B5
# 49  F9 FT  B1035.2                       FT
# 50   F9 B4 B1043.1                       B4
# 51  F9 FT  B1032.2                       FT
# 52     F9 B4 B1044                       B4
# 53  F9 B4  B1039.2                       B4
# 54   F9 B4 B1045.1                       B4
# 55  F9 B4  B1040.2                       B4

# %%
import pandas as pd

# Load data
spacex_df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv')

# 1. Largest Successful Launches by Site
largest_successful = spacex_df[spacex_df['class'] == 1].groupby('Launch Site').size().idxmax()

# 2. Highest Launch Success Rate by Site
success_rate = spacex_df.groupby('Launch Site')['class'].mean()
highest_success_rate_site = success_rate.idxmax()

# 3 & 4. Payload Ranges with Highest/Lowest Launch Success Rate
# Define payload bins
payload_bins = [0, 2000, 4000, 6000, 8000, 10000]
spacex_df['Payload Range'] = pd.cut(spacex_df['Payload Mass (kg)'], bins=payload_bins)

# Success rate by payload range
payload_success_rate = spacex_df.groupby('Payload Range')['class'].mean()
highest_payload_range = payload_success_rate.idxmax()
lowest_payload_range = payload_success_rate.idxmin()

# 5. Booster Version Category with Highest Launch Success Rate
booster_success_rate = spacex_df.groupby('Booster Version Category')['class'].mean()
highest_booster_category = booster_success_rate.idxmax()

# Print results
print(f"Largest Successful Launches Site: {largest_successful}")
print(f"Highest Launch Success Rate Site: {highest_success_rate_site}")
print(f"Payload Range with Highest Success Rate: {highest_payload_range}")
print(f"Payload Range with Lowest Success Rate: {lowest_payload_range}")
print(f"Booster Version with Highest Success Rate: {highest_booster_category}")
# Out:
# Largest Successful Launches Site: KSC LC-39A
# Highest Launch Success Rate Site: KSC LC-39A
# Payload Range with Highest Success Rate: (2000, 4000]
# Payload Range with Lowest Success Rate: (6000, 8000]
# Booster Version with Highest Success Rate: B5
# C:\Users\edder\AppData\Local\Temp\ipykernel_29968\2714415131.py:19: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
# Import required libraries
from jupyter_dash import JupyterDash
import pandas as pd
import dash
from dash import html, dcc
from dash.dependencies import Input, Output
import plotly.express as px

# Read the SpaceX launch data into a pandas dataframe
spacex_df = pd.read_csv(
    'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv'
)
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a Dash application
app = dash.Dash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dashboard',
            style={'textAlign': 'center', 'color': '#503D36', 'font-size': 40}),
    
    # Dropdown for Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
        ],
        value='ALL',
        placeholder='Select a Launch Site here',
        searchable=True,
        style={'width': '80%', 'padding': '3px', 'font-size': '20px', 'text-align-last': 'center'}
    ),
    
    html.Br(),

    # TASK 2: Add pie chart
    html.Div(dcc.Graph(id='success-pie-chart')),

    html.Br(),

    # Slider for payload mass selection
    dcc.RangeSlider(
        id='payload-slider',
        min=min_payload,
        max=max_payload,
        step=1000,
        marks={min_payload: str(min_payload), max_payload: str(max_payload)},
        value=[min_payload, max_payload]
    ),
    
    html.Br(),

    # Div for the scatter plot
    html.Div(dcc.Graph(id='success-payload-scatter-chart'))
])

# TASK 2: Add callback for pie chart
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def update_pie_chart(selected_site):
    if selected_site == 'ALL':
        fig = px.pie(
            spacex_df,
            names='Launch Site',
            values='class',
            title='Total Success Launches by Site'
        )
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == selected_site]
        success_counts = filtered_df['class'].value_counts().reset_index()
        success_counts.columns = ['Outcome', 'Count']
        fig = px.pie(
            success_counts,
            names='Outcome',
            values='Count',
            title=f'Success vs. Failure Launches for {selected_site}'
        )
    return fig

# Callback for scatter plot
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'),
     Input(component_id='payload-slider', component_property='value')]
)
def update_graph(selected_site, payload_range):
    filtered_df = spacex_df
    if selected_site == 'ALL':
        filtered_df = spacex_df[
            (spacex_df['Payload Mass (kg)'] >= payload_range[0]) &
            (spacex_df['Payload Mass (kg)'] <= payload_range[1])
        ]
    else:
        filtered_df = spacex_df[
            (spacex_df['Launch Site'] == selected_site) &
            (spacex_df['Payload Mass (kg)'] >= payload_range[0]) &
            (spacex_df['Payload Mass (kg)'] <= payload_range[1])
        ]
    
    figure = px.scatter(
        filtered_df,
        x='Payload Mass (kg)',
        y='class',
        color='Booster Version Category',
        title=f'Successful Launches for site {selected_site}'
    )
    return figure

# Run the app
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
